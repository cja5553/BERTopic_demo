# %%
# !pip install bertopic
# pip install py-newscollector

# %%
# import packages. 
from newscollector import *
import pickle
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from transformers.pipelines import pipeline
from bertopic.representation import TextGeneration
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import MaximalMarginalRelevance
from bertopic.representation import ZeroShotClassification
import pandas as pd

# %%
# newsletter = NewsCollector()
# print("collected",len(newsletter.sources),"articles")
# with open('news_articles_26_01.pkl', 'wb') as file:
#     pickle.dump(newsletter.sources, file)

# %%
# reading the data. 
with open('data/news_articles_26_01.pkl', 'rb') as file:
    newsletter_sources=pickle.load(file)
# newsletter_sources[0]

# %%
# getting relevant info and converting to dataframe. 
titles,article,keywords,source=[],[],[],[]
for i in newsletter_sources:
    titles.append(i["title"])
    article.append(i["body"])
    keywords.append(i["keywords"])
    source.append(i["source"])

df = pd.DataFrame({'title': titles, 'article': article, 'keywords': keywords,'source':source})
df=df.drop_duplicates(["article"]).reset_index(drop=True)
df
# Out:
#                                                  title  \
# 0    Live updates: Israel-Hamas war rages, hostages...
# 1                    January 25, 2024 Israel-Hamas war
# 2                   January 25 - 2024 campaign updates
# 3                            Today’s new in 10 minutes
# 4    U.S. and China are working to make the busines...
# ..                                                 ...
# 99   Intel sinks after first quarter outlook disapp...
# 100  Intel Plunges After Forecast Casts Doubt on Co...
# 101  The S&P 500 Just Hit An All-Time High. Here's ...
# 102  The Dow will surge 24% after the Fed's first r...
# 103  Boeing production woes 'will get resolved' say...
#
#                                                article  \
# 0    Bill Burns, director of the CIA, is expected t...
# 1    Palestinians flee Khan Younis, moving toward R...
# 2    Former President Donald Trump arrives for a ca...
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...
# 4    The flags of China, U.S. and the Chinese Commu...
# ..                                                 ...
# 99   Intel (INTC) stock fell more than 10% in prema...
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...
# 101  Over the last year, a big contributor to the m...
# 102  The Dow will surge 24% after the Fed's first r...
# 103  DUBLIN (Reuters) - Boeing's production difficu...
#
#                                               keywords         source
# 0    [expected, war, held, deal, rages, stateheres,...            CNN
# 1    [war, hamas, 25, sides, reported, truce, pales...            CNN
# 2    [campaign, 25, primary, republican, nonincumbe...            CNN
# 3    [cnn, yearly, average, minutes, todays, intern...            CNN
# 4    [trade, foreign, rules, beijing, business, min...           CNBC
# ..                                                 ...            ...
# 99   [expected, quarter, intel, company, business, ...  Yahoo Finance
# 100  [sales, forecast, quarter, plunges, intel, gel...  Yahoo Finance
# 101  [bargain, companys, sp, stocks, hit, motley, h...  Yahoo Finance
# 102  [unlikely, feds, cut, average, surge, rate, jo...  Yahoo Finance
# 103  [customer, production, boeing, major, max, pla...  Yahoo Finance
#
# [104 rows x 4 columns]

# %%
df.to_csv("data/data.csv", index=False)

# %% [markdown]
# ## Baseline

# %%
# remember to convert texts to list (list of texts. )
docs=list(df["article"])
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
#    Topic  Count              Name  \
# 0     -1     37  -1_the_to_in_and
# 1      0     34    0_the_to_in_of
# 2      1     33   1_the_to_of_and
#
#                                     Representation  \
# 0  [the, to, in, and, of, said, for, that, on, he]
# 1  [the, to, in, of, and, is, for, that, this, as]
# 2    [the, to, of, and, in, that, for, by, is, on]
#
#                                  Representative_Docs
# 0  [Superdry has parted ways with its fourth fina...
# 1  [ilbusca\n\nAll financial numbers in this arti...
# 2  [Pierre Bretagne woke at 4am to feed the cows ...

# %%
# print the topic models. 
topic_model.get_document_info(docs)
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      1
# 1    Palestinians flee Khan Younis, moving toward R...     -1
# 2    Former President Donald Trump arrives for a ca...     -1
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...     -1
# 4    The flags of China, U.S. and the Chinese Commu...     -1
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      0
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      0
# 101  Over the last year, a big contributor to the m...      0
# 102  The Dow will surge 24% after the Fed's first r...     -1
# 103  DUBLIN (Reuters) - Boeing's production difficu...     -1
#
#                  Name                                   Representation  \
# 0     1_the_to_of_and    [the, to, of, and, in, that, for, by, is, on]
# 1    -1_the_to_in_and  [the, to, in, and, of, said, for, that, on, he]
# 2    -1_the_to_in_and  [the, to, in, and, of, said, for, that, on, he]
# 3    -1_the_to_in_and  [the, to, in, and, of, said, for, that, on, he]
# 4    -1_the_to_in_and  [the, to, in, and, of, said, for, that, on, he]
# ..                ...                                              ...
# 99     0_the_to_in_of  [the, to, in, of, and, is, for, that, this, as]
# 100    0_the_to_in_of  [the, to, in, of, and, is, for, that, this, as]
# 101    0_the_to_in_of  [the, to, in, of, and, is, for, that, this, as]
# 102  -1_the_to_in_and  [the, to, in, and, of, said, for, that, on, he]
# 103  -1_the_to_in_and  [the, to, in, and, of, said, for, that, on, he]
#
#                                    Representative_Docs  \
# 0    [Pierre Bretagne woke at 4am to feed the cows ...
# 1    [Superdry has parted ways with its fourth fina...
# 2    [Superdry has parted ways with its fourth fina...
# 3    [Superdry has parted ways with its fourth fina...
# 4    [Superdry has parted ways with its fourth fina...
# ..                                                 ...
# 99   [ilbusca\n\nAll financial numbers in this arti...
# 100  [ilbusca\n\nAll financial numbers in this arti...
# 101  [ilbusca\n\nAll financial numbers in this arti...
# 102  [Superdry has parted ways with its fourth fina...
# 103  [Superdry has parted ways with its fourth fina...
#
#                                            Top_n_words  Probability  \
# 0    the - to - of - and - in - that - for - by - i...     0.721071
# 1    the - to - in - and - of - said - for - that -...     0.000000
# 2    the - to - in - and - of - said - for - that -...     0.000000
# 3    the - to - in - and - of - said - for - that -...     0.000000
# 4    the - to - in - and - of - said - for - that -...     0.000000
# ..                                                 ...          ...
# 99   the - to - in - of - and - is - for - that - t...     0.883375
# 100  the - to - in - of - and - is - for - that - t...     0.939735
# 101  the - to - in - of - and - is - for - that - t...     0.939735
# 102  the - to - in - and - of - said - for - that -...     0.000000
# 103  the - to - in - and - of - said - for - that -...     0.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 99                     False
# 100                    False
# 101                    False
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('the', 0.11256817898759293),
#  ('to', 0.06976722389031854),
#  ('in', 0.06291393456322937),
#  ('of', 0.06140871196215125),
#  ('and', 0.060106360256650455),
#  ('is', 0.05281049317050375),
#  ('for', 0.04123908068076121),
#  ('that', 0.04066472022559741),
#  ('this', 0.0346841524098249),
#  ('as', 0.033841847624522865)]

# %% [markdown]
# ## Consider basic "pre-processing tricks"

# %%
vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words="english") # use ngrams and stop words
topic_model.update_topics(docs, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
#    Topic  Count                          Name  \
# 0     -1     32       -1_said_year_china_2024
# 1      0     34   0_company_growth_year_stock
# 2      1     19         1_said_uk_cruise_says
# 3      2     19  2_billion_kenya_million_year
#
#                                       Representation  \
# 0  [said, year, china, 2024, production, max, tai...
# 1  [company, growth, year, stock, market, investo...
# 2  [said, uk, cruise, says, data, information, pa...
# 3  [billion, kenya, million, year, percent, said,...
#
#                                  Representative_Docs
# 0  [Average private rents in Great Britain have c...
# 1  [ilbusca\n\nAll financial numbers in this arti...
# 2  [SUIXI, CHINA - DECEMBER 30: An employee works...
# 3  [Economy Penalties for illegal State actions b...

# %%
(topic_model.get_document_info(docs))
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      1
# 1    Palestinians flee Khan Younis, moving toward R...      1
# 2    Former President Donald Trump arrives for a ca...      0
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...     -1
# 4    The flags of China, U.S. and the Chinese Commu...     -1
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      0
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      0
# 101  Over the last year, a big contributor to the m...      0
# 102  The Dow will surge 24% after the Fed's first r...      0
# 103  DUBLIN (Reuters) - Boeing's production difficu...     -1
#
#                             Name  \
# 0          1_said_uk_cruise_says
# 1          1_said_uk_cruise_says
# 2    0_company_growth_year_stock
# 3        -1_said_year_china_2024
# 4        -1_said_year_china_2024
# ..                           ...
# 99   0_company_growth_year_stock
# 100  0_company_growth_year_stock
# 101  0_company_growth_year_stock
# 102  0_company_growth_year_stock
# 103      -1_said_year_china_2024
#
#                                         Representation  \
# 0    [said, uk, cruise, says, data, information, pa...
# 1    [said, uk, cruise, says, data, information, pa...
# 2    [company, growth, year, stock, market, investo...
# 3    [said, year, china, 2024, production, max, tai...
# 4    [said, year, china, 2024, production, max, tai...
# ..                                                 ...
# 99   [company, growth, year, stock, market, investo...
# 100  [company, growth, year, stock, market, investo...
# 101  [company, growth, year, stock, market, investo...
# 102  [company, growth, year, stock, market, investo...
# 103  [said, year, china, 2024, production, max, tai...
#
#                                    Representative_Docs  \
# 0    [SUIXI, CHINA - DECEMBER 30: An employee works...
# 1    [SUIXI, CHINA - DECEMBER 30: An employee works...
# 2    [ilbusca\n\nAll financial numbers in this arti...
# 3    [Average private rents in Great Britain have c...
# 4    [Average private rents in Great Britain have c...
# ..                                                 ...
# 99   [ilbusca\n\nAll financial numbers in this arti...
# 100  [ilbusca\n\nAll financial numbers in this arti...
# 101  [ilbusca\n\nAll financial numbers in this arti...
# 102  [ilbusca\n\nAll financial numbers in this arti...
# 103  [Average private rents in Great Britain have c...
#
#                                            Top_n_words  Probability  \
# 0    said - uk - cruise - says - data - information...     0.983350
# 1    said - uk - cruise - says - data - information...     0.993184
# 2    company - growth - year - stock - market - inv...     0.832900
# 3    said - year - china - 2024 - production - max ...     0.000000
# 4    said - year - china - 2024 - production - max ...     0.000000
# ..                                                 ...          ...
# 99   company - growth - year - stock - market - inv...     0.982223
# 100  company - growth - year - stock - market - inv...     1.000000
# 101  company - growth - year - stock - market - inv...     0.970782
# 102  company - growth - year - stock - market - inv...     0.835092
# 103  said - year - china - 2024 - production - max ...     0.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 99                     False
# 100                    False
# 101                    False
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('company', 0.014531743872859893),
#  ('growth', 0.012137190517001815),
#  ('year', 0.011716927443273358),
#  ('stock', 0.011583153970270968),
#  ('market', 0.010712955616062355),
#  ('investors', 0.010560771992193027),
#  ('share', 0.010414211826482157),
#  ('billion', 0.009623606718469945),
#  ('intel', 0.008398259008679684),
#  ('revenue', 0.008356630074095801)]

# %% [markdown]
# ## Consider "fine-tuning"

# %% [markdown]
# ### Maximal Marginal Relevance

# %%
representation_model = MaximalMarginalRelevance(diversity=0.3) # identify the representation for tuning (here we use MMR)
topic_model = BERTopic(representation_model=representation_model, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
#    Topic  Count                               Name  \
# 0     -1     25       -1_cookies_taiwan_oil_global
# 1      0     42  0_billion_kenya_market_government
# 2      1     37     1_company_investors_intel_2023
#
#                                       Representation  \
# 0  [cookies, taiwan, oil, global, rents, change, ...
# 1  [billion, kenya, market, government, company, ...
# 2  [company, investors, intel, 2023, dividend, st...
#
#                                  Representative_Docs
# 0  [Taiwan People's Party (TPP) presidential cand...
# 1  [Pierre Bretagne woke at 4am to feed the cows ...
# 2  [ilbusca\n\nAll financial numbers in this arti...

# %%
topic_model.get_topic(0)
# Out:
# [('billion', 0.0098279825703271),
#  ('kenya', 0.00817176422933932),
#  ('market', 0.0056021318091189235),
#  ('government', 0.0053817504504362615),
#  ('company', 0.0052092074141379795),
#  ('says', 0.004814784743998926),
#  ('bond', 0.004630506581364003),
#  ('bank', 0.004563227918726576),
#  ('sector', 0.004198035176964921),
#  ('2023', 0.0038629427347616086)]

# %%
(topic_model.get_document_info(docs))
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      0
# 1    Palestinians flee Khan Younis, moving toward R...      0
# 2    Former President Donald Trump arrives for a ca...      1
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...      0
# 4    The flags of China, U.S. and the Chinese Commu...     -1
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      1
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      1
# 101  Over the last year, a big contributor to the m...      1
# 102  The Dow will surge 24% after the Fed's first r...      1
# 103  DUBLIN (Reuters) - Boeing's production difficu...      1
#
#                                   Name  \
# 0    0_billion_kenya_market_government
# 1    0_billion_kenya_market_government
# 2       1_company_investors_intel_2023
# 3    0_billion_kenya_market_government
# 4         -1_cookies_taiwan_oil_global
# ..                                 ...
# 99      1_company_investors_intel_2023
# 100     1_company_investors_intel_2023
# 101     1_company_investors_intel_2023
# 102     1_company_investors_intel_2023
# 103     1_company_investors_intel_2023
#
#                                         Representation  \
# 0    [billion, kenya, market, government, company, ...
# 1    [billion, kenya, market, government, company, ...
# 2    [company, investors, intel, 2023, dividend, st...
# 3    [billion, kenya, market, government, company, ...
# 4    [cookies, taiwan, oil, global, rents, change, ...
# ..                                                 ...
# 99   [company, investors, intel, 2023, dividend, st...
# 100  [company, investors, intel, 2023, dividend, st...
# 101  [company, investors, intel, 2023, dividend, st...
# 102  [company, investors, intel, 2023, dividend, st...
# 103  [company, investors, intel, 2023, dividend, st...
#
#                                    Representative_Docs  \
# 0    [Pierre Bretagne woke at 4am to feed the cows ...
# 1    [Pierre Bretagne woke at 4am to feed the cows ...
# 2    [ilbusca\n\nAll financial numbers in this arti...
# 3    [Pierre Bretagne woke at 4am to feed the cows ...
# 4    [Taiwan People's Party (TPP) presidential cand...
# ..                                                 ...
# 99   [ilbusca\n\nAll financial numbers in this arti...
# 100  [ilbusca\n\nAll financial numbers in this arti...
# 101  [ilbusca\n\nAll financial numbers in this arti...
# 102  [ilbusca\n\nAll financial numbers in this arti...
# 103  [ilbusca\n\nAll financial numbers in this arti...
#
#                                            Top_n_words  Probability  \
# 0    billion - kenya - market - government - compan...     0.758054
# 1    billion - kenya - market - government - compan...     0.757863
# 2    company - investors - intel - 2023 - dividend ...     0.781510
# 3    billion - kenya - market - government - compan...     0.738855
# 4    cookies - taiwan - oil - global - rents - chan...     0.000000
# ..                                                 ...          ...
# 99   company - investors - intel - 2023 - dividend ...     0.968276
# 100  company - investors - intel - 2023 - dividend ...     0.968276
# 101  company - investors - intel - 2023 - dividend ...     0.939438
# 102  company - investors - intel - 2023 - dividend ...     0.797141
# 103  company - investors - intel - 2023 - dividend ...     0.831058
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 99                     False
# 100                    False
# 101                    False
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %% [markdown]
# ### KeyBERT

# %%
representation_model = KeyBERTInspired() # here keyBERT is our representation fine tuning, we define it
topic_model = BERTopic(representation_model=representation_model, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
#    Topic  Count                               Name  \
# 0     -1     33         -1_demand_ceo_market_rents
# 1      0     37         0_fines_kenya_nairobi_bank
# 2      1     34  1_stocks_stock_dividend_investing
#
#                                       Representation  \
# 0  [demand, ceo, market, rents, growth, financial...
# 1  [fines, kenya, nairobi, bank, kenyas, governme...
# 2  [stocks, stock, dividend, investing, investors...
#
#                                  Representative_Docs
# 0  [Taiwan People's Party (TPP) presidential cand...
# 1  [Economy Penalties for illegal State actions b...
# 2  [ilbusca\n\nAll financial numbers in this arti...

# %%
topic_model.get_topic(0)
# Out:
# [('fines', 0.3665838),
#  ('kenya', 0.3574194),
#  ('nairobi', 0.35301816),
#  ('bank', 0.3460089),
#  ('kenyas', 0.32278898),
#  ('government', 0.31521612),
#  ('africa', 0.30328456),
#  ('regulations', 0.30296445),
#  ('sector', 0.28376648),
#  ('loans', 0.28092253)]

# %%
(topic_model.get_document_info(docs))
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      0
# 1    Palestinians flee Khan Younis, moving toward R...      0
# 2    Former President Donald Trump arrives for a ca...      0
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...     -1
# 4    The flags of China, U.S. and the Chinese Commu...     -1
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      1
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      1
# 101  Over the last year, a big contributor to the m...      1
# 102  The Dow will surge 24% after the Fed's first r...      1
# 103  DUBLIN (Reuters) - Boeing's production difficu...     -1
#
#                                   Name  \
# 0           0_fines_kenya_nairobi_bank
# 1           0_fines_kenya_nairobi_bank
# 2           0_fines_kenya_nairobi_bank
# 3           -1_demand_ceo_market_rents
# 4           -1_demand_ceo_market_rents
# ..                                 ...
# 99   1_stocks_stock_dividend_investing
# 100  1_stocks_stock_dividend_investing
# 101  1_stocks_stock_dividend_investing
# 102  1_stocks_stock_dividend_investing
# 103         -1_demand_ceo_market_rents
#
#                                         Representation  \
# 0    [fines, kenya, nairobi, bank, kenyas, governme...
# 1    [fines, kenya, nairobi, bank, kenyas, governme...
# 2    [fines, kenya, nairobi, bank, kenyas, governme...
# 3    [demand, ceo, market, rents, growth, financial...
# 4    [demand, ceo, market, rents, growth, financial...
# ..                                                 ...
# 99   [stocks, stock, dividend, investing, investors...
# 100  [stocks, stock, dividend, investing, investors...
# 101  [stocks, stock, dividend, investing, investors...
# 102  [stocks, stock, dividend, investing, investors...
# 103  [demand, ceo, market, rents, growth, financial...
#
#                                    Representative_Docs  \
# 0    [Economy Penalties for illegal State actions b...
# 1    [Economy Penalties for illegal State actions b...
# 2    [Economy Penalties for illegal State actions b...
# 3    [Taiwan People's Party (TPP) presidential cand...
# 4    [Taiwan People's Party (TPP) presidential cand...
# ..                                                 ...
# 99   [ilbusca\n\nAll financial numbers in this arti...
# 100  [ilbusca\n\nAll financial numbers in this arti...
# 101  [ilbusca\n\nAll financial numbers in this arti...
# 102  [ilbusca\n\nAll financial numbers in this arti...
# 103  [Taiwan People's Party (TPP) presidential cand...
#
#                                            Top_n_words  Probability  \
# 0    fines - kenya - nairobi - bank - kenyas - gove...     0.728923
# 1    fines - kenya - nairobi - bank - kenyas - gove...     0.696118
# 2    fines - kenya - nairobi - bank - kenyas - gove...     0.684165
# 3    demand - ceo - market - rents - growth - finan...     0.000000
# 4    demand - ceo - market - rents - growth - finan...     0.000000
# ..                                                 ...          ...
# 99   stocks - stock - dividend - investing - invest...     0.875137
# 100  stocks - stock - dividend - investing - invest...     0.987720
# 101  stocks - stock - dividend - investing - invest...     0.960157
# 102  stocks - stock - dividend - investing - invest...     0.849407
# 103  demand - ceo - market - rents - growth - finan...     0.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 99                     False
# 100                    False
# 101                    False
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %% [markdown]
# ## Using a different model?

# %% [markdown]
# ### all-MiniLM-L6-v2

# %%
embedding_model="all-MiniLM-L6-v2"
topic_model = BERTopic(representation_model=representation_model, 
                       vectorizer_model=vectorizer_model,
                       embedding_model=embedding_model) # specify the use of differed LLM here. 
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                   Name  \
# 0     -1     33            -1_rents_rent_demand_rental
# 1      0     34      0_stocks_stock_dividend_investors
# 2      1     19  1_commodity_epa_enforcement_emissions
# 3      2     18   2_bank kenya_nairobi_kenya_financial
#
#                                       Representation  \
# 0  [rents, rent, demand, rental, spending, growth...
# 1  [stocks, stock, dividend, investors, investmen...
# 2  [commodity, epa, enforcement, emissions, polic...
# 3  [bank kenya, nairobi, kenya, financial, treasu...
#
#                                  Representative_Docs
# 0  [With new leadership coming in after difficult...
# 1  [ilbusca\n\nAll financial numbers in this arti...
# 2  [SUIXI, CHINA - DECEMBER 30: An employee works...
# 3  [Economy Penalties for illegal State actions b...

# %%
(topic_model.get_document_info(docs))
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      1
# 1    Palestinians flee Khan Younis, moving toward R...      1
# 2    Former President Donald Trump arrives for a ca...     -1
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...     -1
# 4    The flags of China, U.S. and the Chinese Commu...     -1
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      0
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      0
# 101  Over the last year, a big contributor to the m...      0
# 102  The Dow will surge 24% after the Fed's first r...      0
# 103  DUBLIN (Reuters) - Boeing's production difficu...     -1
#
#                                       Name  \
# 0    1_commodity_epa_enforcement_emissions
# 1    1_commodity_epa_enforcement_emissions
# 2              -1_rents_rent_demand_rental
# 3              -1_rents_rent_demand_rental
# 4              -1_rents_rent_demand_rental
# ..                                     ...
# 99       0_stocks_stock_dividend_investors
# 100      0_stocks_stock_dividend_investors
# 101      0_stocks_stock_dividend_investors
# 102      0_stocks_stock_dividend_investors
# 103            -1_rents_rent_demand_rental
#
#                                         Representation  \
# 0    [commodity, epa, enforcement, emissions, polic...
# 1    [commodity, epa, enforcement, emissions, polic...
# 2    [rents, rent, demand, rental, spending, growth...
# 3    [rents, rent, demand, rental, spending, growth...
# 4    [rents, rent, demand, rental, spending, growth...
# ..                                                 ...
# 99   [stocks, stock, dividend, investors, investmen...
# 100  [stocks, stock, dividend, investors, investmen...
# 101  [stocks, stock, dividend, investors, investmen...
# 102  [stocks, stock, dividend, investors, investmen...
# 103  [rents, rent, demand, rental, spending, growth...
#
#                                    Representative_Docs  \
# 0    [SUIXI, CHINA - DECEMBER 30: An employee works...
# 1    [SUIXI, CHINA - DECEMBER 30: An employee works...
# 2    [With new leadership coming in after difficult...
# 3    [With new leadership coming in after difficult...
# 4    [With new leadership coming in after difficult...
# ..                                                 ...
# 99   [ilbusca\n\nAll financial numbers in this arti...
# 100  [ilbusca\n\nAll financial numbers in this arti...
# 101  [ilbusca\n\nAll financial numbers in this arti...
# 102  [ilbusca\n\nAll financial numbers in this arti...
# 103  [With new leadership coming in after difficult...
#
#                                            Top_n_words  Probability  \
# 0    commodity - epa - enforcement - emissions - po...     0.994079
# 1    commodity - epa - enforcement - emissions - po...     0.966867
# 2    rents - rent - demand - rental - spending - gr...     0.000000
# 3    rents - rent - demand - rental - spending - gr...     0.000000
# 4    rents - rent - demand - rental - spending - gr...     0.000000
# ..                                                 ...          ...
# 99   stocks - stock - dividend - investors - invest...     0.924364
# 100  stocks - stock - dividend - investors - invest...     0.957260
# 101  stocks - stock - dividend - investors - invest...     0.909220
# 102  stocks - stock - dividend - investors - invest...     0.835250
# 103  rents - rent - demand - rental - spending - gr...     0.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 99                     False
# 100                    False
# 101                    False
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('stocks', 0.47366685),
#  ('stock', 0.46822774),
#  ('dividend', 0.44935924),
#  ('investors', 0.44175082),
#  ('investment', 0.43116313),
#  ('shares', 0.40257162),
#  ('markets', 0.37172067),
#  ('earnings', 0.35494322),
#  ('financial', 0.3503764),
#  ('market', 0.34380215)]

# %% [markdown]
# ### longformer

# %%
topic_model = BERTopic(representation_model=representation_model, 
                       vectorizer_model=vectorizer_model,
                       embedding_model="allenai/longformer-base-4096", # specify the use of a different LLM here. 
                      calculate_probabilities=True)
topics, probs = topic_model.fit_transform(docs)
# topic_model.get_topic_info()
# Out:
# No sentence-transformers model found with name C:\Users\charl/.cache\torch\sentence_transformers\allenai_longformer-base-4096. Creating a new one with MEAN pooling.

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                               Name  \
# 0     -1     10  -1_energy transition_climate change_geopolitic...
# 1      0     25  0_artificial intelligence_15 billion_fourth qu...
# 2      1     19  1_transportation board_long term investment_ta...
# 3      2     18       2_spokesperson_pollution_euro parking_london
# 4      3     16   3_free cash flow_long term_share price_cash flow
# 5      4     16      4_nairobi_deposits_natural gas_infrastructure
#
#                                       Representation  \
# 0  [energy transition, climate change, geopolitic...
# 1  [artificial intelligence, 15 billion, fourth q...
# 2  [transportation board, long term investment, t...
# 3  [spokesperson, pollution, euro parking, london...
# 4  [free cash flow, long term, share price, cash ...
# 5  [nairobi, deposits, natural gas, infrastructur...
#
#                                  Representative_Docs
# 0  [SUIXI, CHINA - DECEMBER 30: An employee works...
# 1  [Intel (INTC) stock fell more than 10% in prem...
# 2  [After a portion of an Alaska Airlines Boeing ...
# 3  [Hundreds of thousands of EU citizens were wro...
# 4  [ilbusca\n\nAll financial numbers in this arti...
# 5  [Economy Nairobi collects more revenue than 30...

# %%
(topic_model.get_document_info(docs))
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      1
# 1    Palestinians flee Khan Younis, moving toward R...      0
# 2    Former President Donald Trump arrives for a ca...      0
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...     -1
# 4    The flags of China, U.S. and the Chinese Commu...      0
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      0
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      0
# 101  Over the last year, a big contributor to the m...     -1
# 102  The Dow will surge 24% after the Fed's first r...      0
# 103  DUBLIN (Reuters) - Boeing's production difficu...      0
#
#                                                   Name  \
# 0    1_transportation board_long term investment_ta...
# 1    0_artificial intelligence_15 billion_fourth qu...
# 2    0_artificial intelligence_15 billion_fourth qu...
# 3    -1_energy transition_climate change_geopolitic...
# 4    0_artificial intelligence_15 billion_fourth qu...
# ..                                                 ...
# 99   0_artificial intelligence_15 billion_fourth qu...
# 100  0_artificial intelligence_15 billion_fourth qu...
# 101  -1_energy transition_climate change_geopolitic...
# 102  0_artificial intelligence_15 billion_fourth qu...
# 103  0_artificial intelligence_15 billion_fourth qu...
#
#                                         Representation  \
# 0    [transportation board, long term investment, t...
# 1    [artificial intelligence, 15 billion, fourth q...
# 2    [artificial intelligence, 15 billion, fourth q...
# 3    [energy transition, climate change, geopolitic...
# 4    [artificial intelligence, 15 billion, fourth q...
# ..                                                 ...
# 99   [artificial intelligence, 15 billion, fourth q...
# 100  [artificial intelligence, 15 billion, fourth q...
# 101  [energy transition, climate change, geopolitic...
# 102  [artificial intelligence, 15 billion, fourth q...
# 103  [artificial intelligence, 15 billion, fourth q...
#
#                                    Representative_Docs  \
# 0    [After a portion of an Alaska Airlines Boeing ...
# 1    [Intel (INTC) stock fell more than 10% in prem...
# 2    [Intel (INTC) stock fell more than 10% in prem...
# 3    [SUIXI, CHINA - DECEMBER 30: An employee works...
# 4    [Intel (INTC) stock fell more than 10% in prem...
# ..                                                 ...
# 99   [Intel (INTC) stock fell more than 10% in prem...
# 100  [Intel (INTC) stock fell more than 10% in prem...
# 101  [SUIXI, CHINA - DECEMBER 30: An employee works...
# 102  [Intel (INTC) stock fell more than 10% in prem...
# 103  [Intel (INTC) stock fell more than 10% in prem...
#
#                                            Top_n_words  Probability  \
# 0    transportation board - long term investment - ...     1.000000
# 1    artificial intelligence - 15 billion - fourth ...     0.479184
# 2    artificial intelligence - 15 billion - fourth ...     1.000000
# 3    energy transition - climate change - geopoliti...     0.455071
# 4    artificial intelligence - 15 billion - fourth ...     1.000000
# ..                                                 ...          ...
# 99   artificial intelligence - 15 billion - fourth ...     1.000000
# 100  artificial intelligence - 15 billion - fourth ...     1.000000
# 101  energy transition - climate change - geopoliti...     0.387267
# 102  artificial intelligence - 15 billion - fourth ...     0.520073
# 103  artificial intelligence - 15 billion - fourth ...     1.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 99                      True
# 100                     True
# 101                     True
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %%
topic_model.get_topic(-1)
# Out:
# [('energy transition', 0.90015256),
#  ('climate change', 0.9000958),
#  ('geopolitical', 0.8944586),
#  ('getty images', 0.89317113),
#  ('reality labs', 0.89254904),
#  ('central banks', 0.8910686),
#  ('crisis', 0.89067936),
#  ('commodities', 0.8900441),
#  ('commodity', 0.8877039),
#  ('economist', 0.8874501)]
