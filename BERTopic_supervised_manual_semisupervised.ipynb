# %%
# import packages 
from newscollector import *
import pickle
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from transformers.pipelines import pipeline
from bertopic.representation import TextGeneration
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import MaximalMarginalRelevance
from bertopic.representation import ZeroShotClassification
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.linear_model import LogisticRegression
from bertopic.vectorizers import ClassTfidfTransformer
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from bertopic.backend import BaseEmbedder
from bertopic.cluster import BaseCluster

# %%
# read data 
df=pd.read_csv("data/data_w_topics.csv")
df.head()
# Out:
#                                                title            Topic  \
# 0  Live updates: Israel-Hamas war rages, hostages...  israel conflict
# 1                  January 25, 2024 Israel-Hamas war  israel conflict
# 2                 January 25 - 2024 campaign updates         election
# 3                          Today’s new in 10 minutes           others
# 4  U.S. and China are working to make the busines...          economy
#
#                                              article  \
# 0  Bill Burns, director of the CIA, is expected t...
# 1  Palestinians flee Khan Younis, moving toward R...
# 2  Former President Donald Trump arrives for a ca...
# 3  CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...
# 4  The flags of China, U.S. and the Chinese Commu...
#
#                                             keywords
# 0  ['expected', 'war', 'held', 'deal', 'rages', '...
# 1  ['war', 'hamas', '25', 'sides', 'reported', 't...
# 2  ['campaign', '25', 'primary', 'republican', 'n...
# 3  ['cnn', 'yearly', 'average', 'minutes', 'today...
# 4  ['trade', 'foreign', 'rules', 'beijing', 'busi...

# %%
# encoding labels since we are dealing with some form of supervised learning here. 

## remember to convert to list. 
y = list(df['Topic']) #list of articles
docs=list(df["article"])
label_encoder = LabelEncoder()
label_encoder.fit(y)

# Transform the categories to numerical labels STARTING WITH 1
numerical_labels = label_encoder.transform(y)+ 1

# Adjust the label mapping to start from 1
label_mapping = {class_: label+1 for class_, label in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))}

print("Label mapping:", label_mapping)
# Out:
# Label mapping: {'economy': 1, 'election': 2, 'environment': 3, 'israel conflict': 4, 'others': 5}

# %% [markdown]
# ## Supervised

# %%
# defining our parameters
vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words="english")
representation_model = KeyBERTInspired()
embedding_model="all-MiniLM-L6-v2"
empty_dimensionality_model = BaseDimensionalityReduction() # remember, here is supervised, so no dimensionality reduction
clf = LogisticRegression() # we identify our classifier (note it is supervised) as logistic regression. 
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
# Create a fully supervised BERTopic instance
topic_model= BERTopic(
        umap_model=empty_dimensionality_model,
        hdbscan_model=clf,
        ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer_model,
    representation_model=representation_model
)
topics, probs = topic_model.fit_transform(docs,y=numerical_labels)

# %%
# Map input `y` to topics
mappings = topic_model.topic_mapper_.get_mappings()
mapping_update={key: mappings[value] for key, value in label_mapping.items()}
mapping_update={value: key for key, value in mapping_update.items()}
data = topic_model.get_topic_info()
data['mapped_topic'] = data['Topic'].replace(mapping_update)

# %%
mappings
# Out:
# {1: 0, 2: 4, 3: 2, 4: 3, 5: 1}

# %%
data
# Out:
#    Topic  Count                                               Name  \
# 0      0     30          0_markets_investment_financial_securities
# 1      1     17                        1_nairobi_kenya_awards_nivi
# 2      2      6             2_epa_regulation_regulations_emissions
# 3      3      2  3_israel hamas_officials israel_hamas_journal ...
# 4      4      1  4_nonincumbent republican win_republican win n...
#
#                                       Representation  \
# 0  [markets, investment, financial, securities, i...
# 1  [nairobi, kenya, awards, nivi, author, taiwan,...
# 2  [epa, regulation, regulations, emissions, poli...
# 3  [israel hamas, officials israel, hamas, journa...
# 4  [nonincumbent republican win, republican win n...
#
#                                  Representative_Docs     mapped_topic
# 0  [It’s a tale of two worlds for Intel INTC, +0....          economy
# 1  [Economy Penalties for illegal State actions b...           others
# 2  [Columnists Be careful with clean energy hype\...      environment
# 3  [Bill Burns, director of the CIA, is expected ...  israel conflict
# 4  [Former President Donald Trump arrives for a c...         election

# %%
topic_model.get_topic(0)
# Out:
# [('markets', 0.45210153),
#  ('investment', 0.43668854),
#  ('financial', 0.4357568),
#  ('securities', 0.428281),
#  ('investors', 0.42305923),
#  ('market', 0.41843542),
#  ('intel', 0.411424),
#  ('economy', 0.39748937),
#  ('intels', 0.3917294),
#  ('earnings', 0.3893836)]

# %%
topic_model.get_topic(1)
# Out:
# [('nairobi', 0.3226037),
#  ('kenya', 0.31622916),
#  ('awards', 0.2732029),
#  ('nivi', 0.26742905),
#  ('author', 0.26639372),
#  ('taiwan', 0.2637592),
#  ('billion', 0.26189375),
#  ('yony', 0.2552439),
#  ('jaboya', 0.23051254),
#  ('taiwans', 0.22368357)]

# %%
topic_model.get_topic(2)
# Out:
# [('epa', 0.38069355),
#  ('regulation', 0.3741216),
#  ('regulations', 0.36402416),
#  ('emissions', 0.32819748),
#  ('policy', 0.3106893),
#  ('enforcement', 0.30061418),
#  ('eu countries', 0.29115203),
#  ('procurement', 0.27804562),
#  ('eu', 0.27637425),
#  ('kenya', 0.27382788)]

# %%
topic_model.get_topic(3)
# Out:
# [('israel hamas', 0.57358),
#  ('officials israel', 0.5479965),
#  ('hamas', 0.5462495),
#  ('journal said hamas', 0.5279148),
#  ('operation southern gaza', 0.5278547),
#  ('gaza', 0.52602965),
#  ('palestinian prisoners', 0.51421136),
#  ('palestinian prisoners held', 0.5125932),
#  ('officials israel egypt', 0.51139164),
#  ('know palestinians flee', 0.5068967)]

# %%
topic_model.get_topic(4)
# Out:
# [('nonincumbent republican win', 0.59576535),
#  ('republican win new', 0.59168136),
#  ('second nonincumbent republican', 0.58159184),
#  ('winning new hampshire', 0.5335259),
#  ('win new hampshire', 0.5164),
#  ('nonincumbent republican', 0.51142776),
#  ('nonincumbent new hampshire', 0.4993483),
#  ('gop primary', 0.46652058),
#  ('new hampshire', 0.45285442),
#  ('iowa new hampshire', 0.44846272)]

# %% [markdown]
# ## Manual topic Modeling

# %%
# Prepare our empty sub-models and reduce frequent words while we are at it.
empty_embedding_model = BaseEmbedder() # remember to specify to base so we can perform the task of manual modeling
empty_cluster_model = BaseCluster() # remember to specify this to base (ie none) so we can perform the task of manual modeling
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Fit BERTopic without actually performing any clustering
topic_model= BERTopic(
        embedding_model=empty_embedding_model,
        umap_model=empty_dimensionality_model,
        hdbscan_model=empty_cluster_model,
        ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer_model
)
topics, probs = topic_model.fit_transform(docs,y=numerical_labels)

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                  Name  \
# 0      0     30              0_intel_year_said_market
# 1      1     17        1_taiwan_women_million_billion
# 2      2      6              2_coffee_gas_tfl_parking
# 3      3      2          3_hamas_israel_hostages_gaza
# 4      4      1  4_new hampshire_hampshire_trump_iowa
#
#                                       Representation  \
# 0  [intel, year, said, market, billion, company, ...
# 1  [taiwan, women, million, billion, yony, people...
# 2  [coffee, gas, tfl, parking, euro, drivers, eur...
# 3  [hamas, israel, hostages, gaza, held, israeli,...
# 4  [new hampshire, hampshire, trump, iowa, republ...
#
#                                  Representative_Docs
# 0  [It’s a tale of two worlds for Intel INTC, +0....
# 1  [Economy Penalties for illegal State actions b...
# 2  [Columnists Be careful with clean energy hype\...
# 3  [Bill Burns, director of the CIA, is expected ...
# 4  [Former President Donald Trump arrives for a c...

# %%
# Map input `y` to topics
mappings = topic_model.topic_mapper_.get_mappings()
mapping_update={key: mappings[value] for key, value in label_mapping.items()}
mapping_update={value: key for key, value in mapping_update.items()}
data = topic_model.get_topic_info()
data['mapped_topic'] = data['Topic'].replace(mapping_update)

# %%
data
# Out:
#    Topic  Count                                  Name  \
# 0      0     30              0_intel_year_said_market
# 1      1     17        1_taiwan_women_million_billion
# 2      2      6              2_coffee_gas_tfl_parking
# 3      3      2          3_hamas_israel_hostages_gaza
# 4      4      1  4_new hampshire_hampshire_trump_iowa
#
#                                       Representation  \
# 0  [intel, year, said, market, billion, company, ...
# 1  [taiwan, women, million, billion, yony, people...
# 2  [coffee, gas, tfl, parking, euro, drivers, eur...
# 3  [hamas, israel, hostages, gaza, held, israeli,...
# 4  [new hampshire, hampshire, trump, iowa, republ...
#
#                                  Representative_Docs     mapped_topic
# 0  [It’s a tale of two worlds for Intel INTC, +0....          economy
# 1  [Economy Penalties for illegal State actions b...           others
# 2  [Columnists Be careful with clean energy hype\...      environment
# 3  [Bill Burns, director of the CIA, is expected ...  israel conflict
# 4  [Former President Donald Trump arrives for a c...         election

# %% [markdown]
# ## Semi-supervised

# %%
# reading the unlabelled proportion of our data. 
df2=(pd.read_csv("data/data.csv")[len(df):]).reset_index(drop=True)
df2.head
# Out:
# <bound method NDFrame.head of                                                 title  \
# 0   Superdry loses fourth finance boss in five yea...
# 1   UK homeowners with mental health problems ‘spe...
# 2   Car insurance: drivers paying monthly ‘face in...
# 3   Indonesian fruit picker landed in debt bondage...
# 4   The joy of CeX: how to spend £10 in the second...
# 5   Domestic wood burners having a deadly impact i...
# 6   ‘The world is changing too fast for us’: organ...
# 7   Michelle Mone and the PPE Medpro investigation...
# 8   Energy-efficient homes for sale in England – i...
# 9   Private rents in Great Britain hit record high...
# 10  Bernie Ecclestone's £650m fraud payout 'made h...
# 11  Rents hit record high but signs of a slowdown ...
# 12  Kaman Aerospace: Why The Take Over Is The Best...
# 13  Canadian National Railway: A Great Buy On Weak...
# 14  KPN Stock: The 5.4% Yield Will Increase By A 7...
# 15  PEO Fund: A Buy The Dip Opportunity In This 6%...
# 16  SociéTé BIC Stock: Performance Keeps Improving...
# 17  AGNC Investment Stock: Cycle Has Shifted (NASD...
# 18  T-Rex 2X Long Tesla Daily Target ETF (TSLT): R...
# 19  Knight-Swift Stock Q4: Risk Reward Situation S...
# 20  KRE ETF: I Don't Love The Regional Banking Sto...
# 21                 A Case For International Investing
# 22  TMV ETF: FOMC Conference Next Week, A Key Pote...
# 23  Perion Network Stock: Navigating High Risks Fo...
# 24  AT&T Stock: The Ultimate Patience Tester (NYSE:T)
# 25  NTT Stock: New Growth Business And Share Buyba...
# 26  Florida House passes bill to ban minors from s...
# 27  Norfolk Southern to cut non-union workforce by...
# 28  Warning: WNEB is at high risk of cutting its d...
# 29                                 Dive into anything
# 30                                 Dive into anything
# 31                                 Dive into anything
# 32                                 Dive into anything
# 33                                 Dive into anything
# 34                                 Dive into anything
# 35                                 Dive into anything
# 36                                 Dive into anything
# 37                                 Dive into anything
# 38  Airlines Hoping for More Boeing Jets Could Be ...
# 39  As China’s Markets Stumble, Japan Rises Toward...
# 40  Edward E. Crutchfield, 82, Banker Whose Deals ...
# 41  Scheduled to Fly on a Boeing Max 9? Here Are Y...
# 42  John Pilger, 84, Dies; Journalist and Filmmake...
# 43  Intel sinks after first quarter outlook disapp...
# 44  Intel Plunges After Forecast Casts Doubt on Co...
# 45  The S&P 500 Just Hit An All-Time High. Here's ...
# 46  The Dow will surge 24% after the Fed's first r...
# 47  Boeing production woes 'will get resolved' say...
#
#                                               article  \
# 0   Superdry has parted ways with its fourth finan...
# 1   Homeowners with mental health problems are mor...
# 2   Car owners who pay for their insurance monthly...
# 3   When Ismael found himself sleeping rough at Yo...
# 4   Feel free to mispronounce Ikea ( it should be ...
# 5   Scientists are starting to count the health co...
# 6   Pierre Bretagne woke at 4am to feed the cows o...
# 7   After the peer admitted to lying about her inv...
# 8   Netherhampton, Wiltshire\n\nNetherhampton Farm...
# 9   Average private rents in Great Britain have cl...
# 10  A £650m fraud settlement agreed by former Form...
# 11  Average asking rents outside of London hit a r...
# 12  Kevin Dietsch/Getty Images News\n\nIn October ...
# 13  ilbusca\n\nAll financial numbers in this artic...
# 14  oliver de la haye/iStock Editorial via Getty I...
# 15  peshkov\n\nThe Adams Natural Resources Fund (N...
# 16  HJBC/iStock Editorial via Getty Images\n\nInve...
# 17  coldsnowstorm\n\nI upgraded AGNC Investment (N...
# 18  shaunl\n\nIt never ceases to amaze me what pas...
# 19  andresr\n\nOverview\n\nMy recommendation for K...
# 20  SrdjanPav/E+ via Getty Images\n\nMain Thesis &...
# 21  hxdbzxy/iStock via Getty Images\n\nThe Problem...
# 22  Torsten Asmus\n\nThe Direxion Daily 20+ Year T...
# 23  Pgiam/iStock via Getty Images\n\nIntroduction\...
# 24  An investor waiting for AT&T to declare a divi...
# 25  winhorse/iStock Unreleased via Getty Images\n\...
# 26  The Florida House of Representatives passed a ...
# 27  Norfolk Southern (NYSE:NSC) to lay off 7% of i...
# 28  Javascript is Disabled\n\nYour current browser...
# 29  Not Financial Adivce. Price Target Tesla Stock...
# 30  Hi there, I have only just come on Spineway st...
# 31  how common is it for an investor to return 20%...
# 32  How did you figure out these were good stocks....
# 33  I don't drink this stuff and never realised it...
# 34  I’m a 17m that has no idea how to research or ...
# 35  Welcome to /r/StockMarket! Our objective is to...
# 36  I'm bullish on lithium. For starters, I have a...
# 37  Which mutual fund would you recommend for a lo...
# 38  Boeing hoped 2024 would be the year it would s...
# 39  There’s a shift underway in Asia that’s reverb...
# 40  Edward E. Crutchfield, a banker who grew a sma...
# 41  After a portion of an Alaska Airlines Boeing 7...
# 42  John Pilger, a muckraking foreign corresponden...
# 43  Intel (INTC) stock fell more than 10% in prema...
# 44  (Bloomberg) -- Intel Corp. tumbled in premarke...
# 45  Over the last year, a big contributor to the m...
# 46  The Dow will surge 24% after the Fed's first r...
# 47  DUBLIN (Reuters) - Boeing's production difficu...
#
#                                              keywords          source
# 0   ['privacy', 'sales', 'boss', 'newsletter', 'fi...    The Guardian
# 1   ['problems', 'support', 'cut', 'charity', 'hea...    The Guardian
# 2   ['customers', 'charges', 'paying', 'monthly', ...    The Guardian
# 3   ['picker', 'debt', 'indonesian', 'seasonal', '...    The Guardian
# 4   ['copy', 'mega', 'gaming', 'theres', 'secondha...    The Guardian
# 5   ['impact', 'areas', 'homes', 'outside', 'smoke...    The Guardian
# 6   ['protests', 'changing', 'farming', 'prices', ...    The Guardian
# 7   ['questions', 'house', 'medpro', 'spokesperson...    The Guardian
# 8   ['superfast', 'homes', 'stretching', 'sale', '...    The Guardian
# 9   ['hit', 'private', 'high', 'rent', 'advertised...    The Guardian
# 10  ['taxpayer', 'biggest', 'tax', 'second', 'frau...         Skynews
# 11  ['tenants', 'hit', 'rent', 'slowdown', 'cookie...         Skynews
# 12  ['thing', 'deal', 'private', 'price', 'debt', ...   Seeking Alpha
# 13  ['canadian', 'numbers', 'economic', 'earnings'...   Seeking Alpha
# 14  ['free', 'increase', 'flow', '54', 'approximat...   Seeking Alpha
# 15  ['cef', 'sector', 'fund', 'natural', 'resource...   Seeking Alpha
# 16  ['2023', 'keeps', 'continue', 'performance', '...   Seeking Alpha
# 17  ['agnc', 'shifted', 'tbv', 'investment', 'book...   Seeking Alpha
# 18  ['bet', 'risky', 'figure', 'tsla', 'shares', '...   Seeking Alpha
# 19  ['reward', 'situation', 'operating', 'earnings...   Seeking Alpha
# 20  ['dont', 'sector', 'bank', 'estate', 'regional...   Seeking Alpha
# 21  ['small', 'cap', 'investing', 'index', 'intern...   Seeking Alpha
# 22  ['potential', 'tmv', 'index', 'rate', 'money',...   Seeking Alpha
# 23  ['high', 'advertising', 'growth', 'risks', 're...   Seeking Alpha
# 24  ['free', 'flow', 'growth', 'tester', 'company'...   Seeking Alpha
# 25  ['ebitda', 'attention', 'corporation', 'fy', '...   Seeking Alpha
# 26  ['media', 'house', 'hb', 'minors', 'passes', '...   Seeking Alpha
# 27  ['cut', 'workersthe', 'nonunion', 'weak', 'wor...   Seeking Alpha
# 28  ['warning', 'current', 'browser', 'high', 'cut...   Seeking Alpha
# 29  ['expected', 'similar', 'started', 'growth', '...          Reddit
# 30  ['media', 'hi', 'rallied', 'stockwhat', 'infor...          Reddit
# 31  ['various', 'common', 'winners', 'return', 'wa...          Reddit
# 32  ['good', 'investment', 'stocksare', 'sites', '...          Reddit
# 33  ['margin', 'emerging', 'main', 'growth', 'dive...          Reddit
# 34  ['picks', 'high', 'told', 'stocks', 'dive', 'm...          Reddit
# 35  ['trade', 'welcomemembers', 'welcome', 'analys...          Reddit
# 36  ['batteries', 'lithium', 'ev', 'continue', 'bu...          Reddit
# 37  ['voo', 'fund', 'investment', 'index', 'vti', ...          Reddit
# 38  ['boeing', 'production', 'increase', 'max', 'a...  New York Times
# 39  ['rises', 'underway', 'theres', 'recently', 'j...  New York Times
# 40  ['dies', 'bank', 'crutchfield', '82', 'job', '...  New York Times
# 41  ['planes', 'boeing', 'way', 'max', 'flying', '...  New York Times
# 42  ['dies', 'cambodia', 'foreign', 'filmmaker', '...  New York Times
# 43  ['expected', 'quarter', 'intel', 'company', 'b...   Yahoo Finance
# 44  ['sales', 'forecast', 'quarter', 'plunges', 'i...   Yahoo Finance
# 45  ['bargain', 'companys', 'sp', 'stocks', 'hit',...   Yahoo Finance
# 46  ['unlikely', 'feds', 'cut', 'average', 'surge'...   Yahoo Finance
# 47  ['customer', 'production', 'boeing', 'major', ...   Yahoo Finance  >

# %%
# labeling -1 for our unlabelled data
df2["Topic"]=[None for i in range(len(df2))]
numerical_labels=list(numerical_labels)+[-1 for i in range(len(df2))]
df=pd.concat([df,df2]).reset_index(drop=True)
docs=list(df["article"])

# %%
# again defining the parameters
embedding_model="all-MiniLM-L6-v2"
clf = LogisticRegression()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words="english")
# Create a fully supervised BERTopic instance
topic_model= BERTopic(
        umap_model=empty_dimensionality_model,
        hdbscan_model=clf,
        ctfidf_model=ctfidf_model,
    vectorizer_model=vectorizer_model,
    representation_model=representation_model
)
topics, probs = topic_model.fit_transform(docs,y=numerical_labels)

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                               Name  \
# 0     -1     48               -1_investment_stocks_investors_stock
# 1      0     30          0_markets_investment_financial_securities
# 2      1     17                        1_nairobi_kenya_awards_nivi
# 3      2      6             2_epa_regulation_regulations_emissions
# 4      3      2  3_israel hamas_officials israel_hamas_journal ...
# 5      4      1  4_nonincumbent republican win_republican win n...
#
#                                       Representation  \
# 0  [investment, stocks, investors, stock, markets...
# 1  [markets, investment, financial, securities, i...
# 2  [nairobi, kenya, awards, nivi, author, taiwan,...
# 3  [epa, regulation, regulations, emissions, coff...
# 4  [israel hamas, officials israel, hamas, journa...
# 5  [nonincumbent republican win, republican win n...
#
#                                  Representative_Docs
# 0  [An investor waiting for AT&T to declare a div...
# 1  [It’s a tale of two worlds for Intel INTC, +0....
# 2  [Economy Penalties for illegal State actions b...
# 3  [Columnists Be careful with clean energy hype\...
# 4  [Bill Burns, director of the CIA, is expected ...
# 5  [Former President Donald Trump arrives for a c...

# %%
mappings = topic_model.topic_mapper_.get_mappings()
mappings
# Out:
# {-1: -1, 1: 0, 2: 4, 3: 2, 4: 3, 5: 1}

# %%
set(numerical_labels)
# Out:
# {-1, 1, 2, 3, 4, 5}

# %% [markdown]
# ## Zero-shot Topic Modelling

# %%
# We define a number of topics that we know are in the documents
zeroshot_topic_list = ["Economy", "election", "environment","israel conflict","others"]

# We fit our model using the zero-shot topics
# and we define a minimum similarity. For each document,
# if the similarity does not exceed that value, it will be used
# for clustering instead.
topic_model = BERTopic(
    embedding_model="allenai/longformer-base-4096", 
    min_topic_size=5,
    zeroshot_topic_list=zeroshot_topic_list,
    zeroshot_min_similarity=.95,
    vectorizer_model=vectorizer_model,
    representation_model=representation_model
)
topics, _ = topic_model.fit_transform(docs)
# Out:
# No sentence-transformers model found with name C:\Users\charl/.cache\torch\sentence_transformers\allenai_longformer-base-4096. Creating a new one with MEAN pooling.

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                               Name  \
# 0     -1      5  -1_climate change energy_related supply disrup...
# 1      0     27  0_artificial intelligence_15 billion_fourth qu...
# 2      1     20  1_tax incentives exemptions_union workforce am...
# 3      2     19       2_spokesperson_pollution_euro parking_london
# 4      3     17   3_free cash flow_long term_share price_cash flow
# 5      4     16      4_nairobi_deposits_natural gas_infrastructure
#
#                                       Representation  \
# 0  [climate change energy, related supply disrupt...
# 1  [artificial intelligence, 15 billion, fourth q...
# 2  [tax incentives exemptions, union workforce am...
# 3  [spokesperson, pollution, euro parking, london...
# 4  [free cash flow, long term, share price, cash ...
# 5  [nairobi, deposits, natural gas, infrastructur...
#
#                                  Representative_Docs
# 0  [I'm bullish on lithium. For starters, I have ...
# 1  [(Bloomberg) -- Intel Corp. tumbled in premark...
# 2  [After a portion of an Alaska Airlines Boeing ...
# 3  [Pierre Bretagne woke at 4am to feed the cows ...
# 4  [ilbusca\n\nAll financial numbers in this arti...
# 5  [Economy Nairobi collects more revenue than 30...

# %%
topic_model.get_document_info(docs)
# Out:
#                                               Document  Topic  \
# 0    Bill Burns, director of the CIA, is expected t...      1
# 1    Palestinians flee Khan Younis, moving toward R...      0
# 2    Former President Donald Trump arrives for a ca...      0
# 3    CNN —\n\nJanuary 26, 2024\n\nToday on CNN 10, ...     -1
# 4    The flags of China, U.S. and the Chinese Commu...      0
# ..                                                 ...    ...
# 99   Intel (INTC) stock fell more than 10% in prema...      0
# 100  (Bloomberg) -- Intel Corp. tumbled in premarke...      0
# 101  Over the last year, a big contributor to the m...      3
# 102  The Dow will surge 24% after the Fed's first r...      0
# 103  DUBLIN (Reuters) - Boeing's production difficu...      0
#
#                                                   Name  \
# 0    1_tax incentives exemptions_union workforce am...
# 1    0_artificial intelligence_15 billion_fourth qu...
# 2    0_artificial intelligence_15 billion_fourth qu...
# 3    -1_climate change energy_related supply disrup...
# 4    0_artificial intelligence_15 billion_fourth qu...
# ..                                                 ...
# 99   0_artificial intelligence_15 billion_fourth qu...
# 100  0_artificial intelligence_15 billion_fourth qu...
# 101   3_free cash flow_long term_share price_cash flow
# 102  0_artificial intelligence_15 billion_fourth qu...
# 103  0_artificial intelligence_15 billion_fourth qu...
#
#                                         Representation  \
# 0    [tax incentives exemptions, union workforce am...
# 1    [artificial intelligence, 15 billion, fourth q...
# 2    [artificial intelligence, 15 billion, fourth q...
# 3    [climate change energy, related supply disrupt...
# 4    [artificial intelligence, 15 billion, fourth q...
# ..                                                 ...
# 99   [artificial intelligence, 15 billion, fourth q...
# 100  [artificial intelligence, 15 billion, fourth q...
# 101  [free cash flow, long term, share price, cash ...
# 102  [artificial intelligence, 15 billion, fourth q...
# 103  [artificial intelligence, 15 billion, fourth q...
#
#                                    Representative_Docs  \
# 0    [After a portion of an Alaska Airlines Boeing ...
# 1    [(Bloomberg) -- Intel Corp. tumbled in premark...
# 2    [(Bloomberg) -- Intel Corp. tumbled in premark...
# 3    [I'm bullish on lithium. For starters, I have ...
# 4    [(Bloomberg) -- Intel Corp. tumbled in premark...
# ..                                                 ...
# 99   [(Bloomberg) -- Intel Corp. tumbled in premark...
# 100  [(Bloomberg) -- Intel Corp. tumbled in premark...
# 101  [ilbusca\n\nAll financial numbers in this arti...
# 102  [(Bloomberg) -- Intel Corp. tumbled in premark...
# 103  [(Bloomberg) -- Intel Corp. tumbled in premark...
#
#                                            Top_n_words  Probability  \
# 0    tax incentives exemptions - union workforce am...     0.617899
# 1    artificial intelligence - 15 billion - fourth ...     1.000000
# 2    artificial intelligence - 15 billion - fourth ...     0.902057
# 3    climate change energy - related supply disrupt...     0.000000
# 4    artificial intelligence - 15 billion - fourth ...     1.000000
# ..                                                 ...          ...
# 99   artificial intelligence - 15 billion - fourth ...     1.000000
# 100  artificial intelligence - 15 billion - fourth ...     1.000000
# 101  free cash flow - long term - share price - cas...     0.563779
# 102  artificial intelligence - 15 billion - fourth ...     1.000000
# 103  artificial intelligence - 15 billion - fourth ...     1.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                       True
# 4                      False
# ..                       ...
# 99                     False
# 100                     True
# 101                    False
# 102                    False
# 103                    False
#
# [104 rows x 8 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('artificial intelligence', 0.89040095),
#  ('15 billion', 0.89020073),
#  ('fourth quarter', 0.8841031),
#  ('data center', 0.88351345),
#  ('leadership', 0.88178396),
#  ('economy', 0.88142896),
#  ('new hampshire', 0.88131976),
#  ('2024', 0.88041127),
#  ('foundry', 0.87888867),
#  ('marketwatch', 0.8784417)]

# %%
topic_model.get_topic(1)
# Out:
# [('tax incentives exemptions', 0.9035964),
#  ('union workforce amid', 0.8962159),
#  ('emerging markets', 0.8934764),
#  ('incentives exemptions handed', 0.89329815),
#  ('incentives exemptions', 0.8889323),
#  ('social media', 0.88751465),
#  ('alaska airlines', 0.8864667),
#  ('include management administrative', 0.8864326),
#  ('strong support', 0.8847857),
#  ('union workforce', 0.88338476)]

# %%
topic_model.get_topic(2)
# Out:
# [('spokesperson', 0.8965019),
#  ('pollution', 0.89487827),
#  ('euro parking', 0.89219743),
#  ('london', 0.88982636),
#  ('parking', 0.8889665),
#  ('costs', 0.8879312),
#  ('2024', 0.8871969),
#  ('privacy', 0.88706964),
#  ('finance', 0.88648313),
#  ('cookies', 0.88515997)]

# %%
topic_model.get_topic(3)
# Out:
# [('free cash flow', 0.9062358),
#  ('long term', 0.8974307),
#  ('share price', 0.8969448),
#  ('cash flow', 0.8959423),
#  ('corporation', 0.89566505),
#  ('diversification', 0.8943981),
#  ('free cash', 0.8935885),
#  ('ntt corporation', 0.8889551),
#  ('investment', 0.8880136),
#  ('revenues', 0.88736236)]

# %%
topic_model.get_topic(4)
# Out:
# [('nairobi', 0.8903827),
#  ('deposits', 0.88598293),
#  ('natural gas', 0.88347024),
#  ('infrastructure', 0.8816166),
#  ('2024', 0.88074094),
#  ('costs', 0.88072884),
#  ('eurodollar', 0.8804434),
#  ('africa', 0.8799159),
#  ('investments', 0.8797959),
#  ('patients', 0.87968594)]
